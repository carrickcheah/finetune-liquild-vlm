# %% [markdown]
# # Evaluation Results Visualization
#
# This notebook loads and visualizes evaluation results from CSV files with embedded images.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Print all evaluation samples

# %%
from ft_vlm.evaluation import EvalReport

eval_report = EvalReport.from_last_csv()

# You can algo pick a specifc csv file to visualize from the evals/ folder
# For example, if you want to visualize the file predictions/predictions_20250925_143241.csv you do the following:

# file_name = "predictions_20251105_230749.csv" # LFM2-VL-3B -> 81%
file_name = "predictions_20251117_214337.csv" # checkpoint-1000 -> 82%
eval_report = EvalReport.from_csv(file_name)

eval_report.print_confusion_matrix()
# Out:
# Number of classes: 89
# Classes: ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'can', 'castle', 'cattle', 'chair', 'chimpanzee', 'clock', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dolphin', 'elephant', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plate', 'poppy', 'possum', 'rabbit', 'raccoon', 'road', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'woman', 'worm']
# Total predictions: 200
# Correct predictions: 125
# Accuracy: 0.625

# %% [markdown]
# ## Calculate Accuracy

# %%
eval_report.get_accuracy()
# Out:
# 0.625

# %% [markdown]
# ## Print only misclassified samples

# %%
eval_report.print(only_misclassified=True)
